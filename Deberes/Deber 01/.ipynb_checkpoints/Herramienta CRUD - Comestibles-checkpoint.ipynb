# %%
comestibles = []
class Comestible:
    producto = None
    precio = None
    cantidad = None
    fecha_caducidad = None
    empresa = None
    
    def __init__ (self, producto, precio, cantidad, fecha_caducidad, empresa):
        self.producto = producto
        self.precio = precio
        self.cantidad = cantidad
        self.fecha_caducidad = fecha_caducidad
        self.empresa = empresa
        
    def __str__(self):
        return f"Producto: {self.producto} Precio: {self.precio} Cantidad: {self.cantidad} Fecha de Caducidad:{self.fecha_caducidad} Empresa: {self.empresa}"
    
def nuevo_producto():
        producto = input("Ingresar prodcuto nuevo:\n")
        precio = input ("Ingresar precio del prodcuto:\n")
        cantidad = input("Cantidad a ingresar del producto (paquetes/fundas):\n")
        fecha_caducidad = input("Fecha de caducidad del producto:\n")
        empresa = input("Ingresar proveedor:\n")
        comestibles.append(Comestible(producto, precio, cantidad, fecha_caducidad, empresa))
        print(".....Producto Ingresado.....\n")

def guardar_prodcuto():
    try: 
        path = "./Comestibles.txt"
        archivo_abierto = open(path, 'w')
        guardar=""
        for pro_nuevo in comestibles:
            guardar +=pro_nuevoo.producto+" - "+pro_nuevo.precio+" - "+pro_nuevoro.cantidad+" - "+pro_nuevo.fecha_caducidad+" - "+pro_nuevo.empresa
        archivo_abierto.write(guardar)
        archivo_abierto.close()
    except Exception as Error:
        print("Error al Guardar...!!!")

def imprimir_productos():
    try:
        path = "./Comestibles.txt"
        archivo_abierto = open(path)
        lineas = archivo_abierto.readlines()
        print(lineas)
        archivo_abierto.close()
    except Exception as Error:
        print("Error leyendo archivo")
        
def actualizar_producto():
    producto = input("Ingresar producto a actualizar:\n")
    existe = False
    for i in comestibles:
        if(producto == i.producto):
            comestibles.remove(i)
            nuevo_producto()
            existe = True
            print(".....Producto Actualizado.....\n")
        else:
            print("Prodcuto no existe en base...!!!\n")

def eliminar_producto():
    producto = input("Ingresar producto a ELIMINAR:\n")
    existe = False
    for i in comestibles:
        if(producto== i.producto):
            comestibles.remove(i)
            existe = True
            print(".....Producto Eliminado.....")
        else:
            print("Producto no Existe...!!!\n")

# %%
proveedor = []
class Empresa:
    nombre = None
    jefe = None
    telefono = None
    correo = None
    sede = None
    
    def __init__ (self, nombre, jefe, telefono, correo, sede):
        self.nombre = nombre
        self.jefe = jefe
        self.telefono = telefono
        self.correo = correo
        self.sede = sede
        
    def __str__(self):
        return f"Empresa: {self.nombre} Jefe Ejecutivo: {self.jefe} Teléfono: {self.telefono} Correo:{self.correo} Sede: {self.sede}"
    
def nueva_empresa():
        nombre = input("Ingresar nombre de la empresa:\n")
        jefe = input ("Ingresar nombre del Jefe Ejecutivo:\n")
        telefono = input("Ingresar Telefono:\n")
        correo = input("Ingresar correo:\n")
        sede = input("Ingresar sede proveedora:\n")
        proveedor.append(Empresa(nombre, jefe, telefono, correo, sede))
        print(".....Empresa Ingresada.....\n")

def guardar_empresa():
    try: 
        path = "./Empresas.txt"
        archivo_abierto = open(path, 'w')
        guardar=""
        for emp_nueva in proveedor:
            guardar +=emp_nueva.nombre+" - "+emp_nueva.jefe+" - "+emp_nueva.telefono+" - "+emp_nueva.correo+" - "+emp_nueva.sede
        archivo_abierto.write(guardar)
        archivo_abierto.close()
    except Exception as Error:
        print("Error al Guardar...!!!")
        
def imprimir_empresas():
    try:
        path = "./Empresas.txt"
        archivo_abierto = open(path)
        lineas = archivo_abierto.readlines()
        print(lineas)
        archivo_abierto.close()
    except Exception as Error:
        print("Error leyendo archivo")
        
def actualizar_empresa():
    nombre = input("Ingresar empresa a actualizar:\n")
    existe = False
    for i in proveedor:
        if(nombreo == i.nombre):
            proveedor.remove(i)
            nueva_empresa()
            existe = True
            print(".....Empresa Actualizada.....\n")
        else:
            print("Empresa no Existe en Base...!!!\n")

def eliminar_empresa():
    nombre = input("Ingresar empresa a ELIMINAR:\n")
    existe = False
    for i in proveedor:
        if(nombre == i.nombre):
            proveedor.remove(i)
            existe = True
            print(".....Empresa Eliminada.....")
        else:
            print("Empresaa no Existe en Base...!!!\n")
#    for i in comestibles:
#        if(nombre == i.nombre):
#            proveedor.remove(i)
#            existe = True
#            print(".....Empresa Eliminada.....")

# %%
while True:
    print("\nHerramienta CRUD - Empresas y Comestibles\n")
    print("\tQue desea hacer....?")
    opc = str(input ("1. Ingresar Nueva Empresa\n2. Mostrar Lista de Empresas\n"
                     "3. Actualizar Empresa\n4. Eliminar Empresa\n5. Ingresar Nuevo Producto\n"
                     "6. Mostar Lista de Prodcutos\n7. Actualizar Producto\n8. Eliminar Prodcuto\n9. Salir\n"))
    if opc == "1":
        print ("Ingresar Nueva Empresa\n") 
        nueva_empresa()
        guardar_empresa() 
    elif opc == "2" :
        print("Lista de Empresas Registradas\n")
        imprimir_empresas()
    elif opc == "3":
        print("Actualizar Empresa\n")
        imprimir_empresas()
        actualizar_empresa()
        guardar_empresa()
    elif opc =="4":
        print("Eliminar Empresa\n")
        imprimir_empresa()
        eliminar_auto()
    elif opc =="5":
        print("Ingresar Nuevo Producto\n")
        nuevo_producto()
        guardar_prodcuto()
    elif opc == "6":
        print("Lista de Prodcutos Registrados\n")
        imprimir_productos()
    elif opc == "7":
        imprimir_productos()
        actualizar_producto()
    elif opc == "8":
        eliminar_producto()
    elif opc=="9":
        print("Gracias por Venir........")
        break
# Out:
# Herramienta CRUD - Empresas y Comestibles
#
# 	Que desea hacer....?
# 1. Ingresar Nueva Empresa
# 2. Mostrar Lista de Empresas
# 3. Actualizar Empresa
# 4. Eliminar Empresa
# 5. Ingresar Nuevo Producto
# 6. Mostar Lista de Prodcutos
# 7. Actualizar Producto
# 8. Eliminar Prodcuto
# 9. Salir
# 6
# Lista de Prodcutos Registrados
#
# []
#
# Herramienta CRUD - Empresas y Comestibles
#
# 	Que desea hacer....?
